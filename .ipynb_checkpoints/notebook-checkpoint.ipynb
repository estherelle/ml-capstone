# %%
# Code from Kaggle kernels were referenced and built upon for this project. 
# I want to make that clear from the start to avoid any potential confusion. 
# Additionally, there is also code straight from documentation that has been adapted 
# and used for development and testing purposes.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from subprocess import check_output
# print(check_output(["ls", "../input"]).decode("utf8"))

# %%
DATA_FILE = '../input/spam.csv'
df = pd.read_csv(DATA_FILE,encoding='latin-1')

# drop extraneous columns
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)
print(df.head())

labels = df.v1
messages = df.v2

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from sklearn.preprocessing import LabelEncoder
import time
from keras import metrics
print('\nimport done')
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
# import done

# %%
# rename the column names to label and text
df = df.rename(columns={"v1": "label", "v2":"text"})
print(df.head())
df.label.value_counts()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
# ham     4825
# spam     747
# Name: label, dtype: int64

# %%
spam = df[df.label == 'spam']
ham = df[df.label == 'ham']

from keras.preprocessing.text import text_to_word_sequence

def wordFreqs(text):
    msgs = {}
    for msg in text:
        words = text_to_word_sequence(msg)
        for word in words:
            # try and get more significant words
            if len(word) > 3:
                try:
                    msgs[word] += 1
                except:
                    msgs[word] = 1
    return msgs

spamDict = wordFreqs(spam.text)
hamDict = wordFreqs(ham.text)

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.feature_extraction.text import TfidfVectorizer
# # vectorizer = CountVectorizer()
# # vectorizer.fit(spam.text)

# spamVectorizer = TfidfVectorizer()
# spamVectorizer.fit(spam.text)
# spamDict = spamVectorizer.vocabulary_
# # print(vectorizer.vocabulary_)

# hamVectorizer = TfidfVectorizer()
# hamVectorizer.fit(ham.text)
# hamDict = hamVectorizer.vocabulary_

# %%
# Benchmark
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier

X_train,X_test,y_train,y_test = train_test_split(df["text"],df["label"], test_size = 0.2, random_state = 10)
vectorizer = TfidfVectorizer()
vectorizer.fit(X_train)
X_train_df = vectorizer.transform(X_train)
X_test_df = vectorizer.transform(X_test)

model = KNeighborsClassifier(n_neighbors=4)
model.fit(X_train_df, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#            weights='uniform')

# %%
from sklearn.metrics import accuracy_score
prediction = model.predict(X_test_df)
accuracy_score(y_test, prediction)
# Out:
# 0.90403587443946187

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

spamWordcloud = WordCloud(width=600,height=400, max_words=1000,relative_scaling=1,normalize_plurals=False).generate_from_frequencies(spamDict)
hamWordcloud = WordCloud(width=600,height=400, max_words=1000,relative_scaling=1,normalize_plurals=False).generate_from_frequencies(hamDict)

# %%
#Spam Word cloud
plt.figure( figsize=(10,8), facecolor='k')
plt.imshow(spamWordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
#Spam Word cloud
plt.figure( figsize=(10,8), facecolor='k')
plt.imshow(hamWordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
max_words = 1000
num_max = max_words
# preprocess
le = LabelEncoder()
labels = le.fit_transform(labels)
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(messages)
mat_texts = tok.texts_to_matrix(messages,mode='count')
print(labels[:5])
print(mat_texts[:5])
print(labels.shape,mat_texts.shape)

# %%
# try a simple model first
def get_simple_model():
    model = Sequential()
    model.add(Dense(512, activation='relu', input_shape=(num_max,)))
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()
    model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['acc',metrics.binary_accuracy])
    return model

def check_model(model,x,y):
    model.fit(x,y,batch_size=32,epochs=10,verbose=1,validation_split=0.2)

m = get_simple_model()
check_model(m,mat_texts,labels)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               512512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 644,097
# Trainable params: 644,097
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4457 samples, validate on 1115 samples
# Epoch 1/10
# 4457/4457 [==============================] - 4s 952us/step - loss: 0.1627 - acc: 0.9504 - binary_accuracy: 0.9504 - val_loss: 0.0624 - val_acc: 0.9857 - val_binary_accuracy: 0.9857
# Epoch 2/10
# 4457/4457 [==============================] - 4s 905us/step - loss: 0.0342 - acc: 0.9908 - binary_accuracy: 0.9908 - val_loss: 0.0595 - val_acc: 0.9865 - val_binary_accuracy: 0.9865
# Epoch 3/10
# 4457/4457 [==============================] - 4s 890us/step - loss: 0.0099 - acc: 0.9973 - binary_accuracy: 0.9973 - val_loss: 0.0716 - val_acc: 0.9883 - val_binary_accuracy: 0.9883
# Epoch 4/10
# 4457/4457 [==============================] - 4s 882us/step - loss: 0.0050 - acc: 0.9987 - binary_accuracy: 0.9987 - val_loss: 0.0755 - val_acc: 0.9848 - val_binary_accuracy: 0.9848
# Epoch 5/10
# 4457/4457 [==============================] - 4s 874us/step - loss: 0.0025 - acc: 0.9993 - binary_accuracy: 0.9993 - val_loss: 0.0906 - val_acc: 0.9874 - val_binary_accuracy: 0.9874
# Epoch 6/10
# 4457/4457 [==============================] - 4s 913us/step - loss: 0.0025 - acc: 0.9993 - binary_accuracy: 0.9993 - val_loss: 0.0944 - val_acc: 0.9865 - val_binary_accuracy: 0.9865
# Epoch 7/10
# 4457/4457 [==============================] - 4s 855us/step - loss: 0.0019 - acc: 0.9998 - binary_accuracy: 0.9998 - val_loss: 0.1001 - val_acc: 0.9865 - val_binary_accuracy: 0.9865
# Epoch 8/10
# 4457/4457 [==============================] - 4s 874us/step - loss: 0.0016 - acc: 0.9998 - binary_accuracy: 0.9998 - val_loss: 0.0950 - val_acc: 0.9874 - val_binary_accuracy: 0.9874
# Epoch 9/10
# 4457/4457 [==============================] - 4s 858us/step - loss: 0.0016 - acc: 0.9998 - binary_accuracy: 0.9998 - val_loss: 0.1022 - val_acc: 0.9865 - val_binary_accuracy: 0.9865
# Epoch 10/10
# 4457/4457 [==============================] - 4s 892us/step - loss: 0.0015 - acc: 0.9998 - binary_accuracy: 0.9998 - val_loss: 0.1016 - val_acc: 0.9857 - val_binary_accuracy: 0.9857

# %%
def get_model():
    model = Sequential()
    model.add(Dense(512, activation='relu', input_shape=(num_max,)))
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='tanh'))
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()
    model.compile(loss='binary_crossentropy',
              optimizer='adagrad',
              metrics=['acc',metrics.binary_accuracy])
    return model

m = get_model()
check_model(m,mat_texts,labels)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 512)               512512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 676,865
# Trainable params: 676,865
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4457 samples, validate on 1115 samples
# Epoch 1/10
# 4457/4457 [==============================] - 3s 686us/step - loss: 0.1090 - acc: 0.9672 - binary_accuracy: 0.9672 - val_loss: 0.0583 - val_acc: 0.9874 - val_binary_accuracy: 0.9874
# Epoch 2/10
# 4457/4457 [==============================] - 3s 709us/step - loss: 0.0309 - acc: 0.9919 - binary_accuracy: 0.9919 - val_loss: 0.0615 - val_acc: 0.9901 - val_binary_accuracy: 0.9901
# Epoch 3/10
# 4457/4457 [==============================] - 3s 677us/step - loss: 0.0091 - acc: 0.9971 - binary_accuracy: 0.9971 - val_loss: 0.0749 - val_acc: 0.9865 - val_binary_accuracy: 0.9865
# Epoch 4/10
# 4457/4457 [==============================] - 3s 738us/step - loss: 0.0046 - acc: 0.9989 - binary_accuracy: 0.9989 - val_loss: 0.0877 - val_acc: 0.9883 - val_binary_accuracy: 0.9883
# Epoch 5/10
# 4457/4457 [==============================] - 3s 669us/step - loss: 0.0034 - acc: 0.9991 - binary_accuracy: 0.9991 - val_loss: 0.1021 - val_acc: 0.9883 - val_binary_accuracy: 0.9883
# Epoch 6/10
# 4457/4457 [==============================] - 3s 673us/step - loss: 0.0031 - acc: 0.9991 - binary_accuracy: 0.9991 - val_loss: 0.1068 - val_acc: 0.9883 - val_binary_accuracy: 0.9883
# Epoch 7/10
# 4457/4457 [==============================] - 3s 673us/step - loss: 0.0021 - acc: 0.9996 - binary_accuracy: 0.9996 - val_loss: 0.1045 - val_acc: 0.9865 - val_binary_accuracy: 0.9865
# Epoch 8/10
# 4457/4457 [==============================] - 3s 656us/step - loss: 0.0019 - acc: 0.9998 - binary_accuracy: 0.9998 - val_loss: 0.1098 - val_acc: 0.9883 - val_binary_accuracy: 0.9883
# Epoch 9/10
# 4457/4457 [==============================] - 3s 695us/step - loss: 0.0018 - acc: 0.9998 - binary_accuracy: 0.9998 - val_loss: 0.1107 - val_acc: 0.9883 - val_binary_accuracy: 0.9883
# Epoch 10/10
# 4457/4457 [==============================] - 3s 742us/step - loss: 0.0015 - acc: 0.9998 - binary_accuracy: 0.9998 - val_loss: 0.1117 - val_acc: 0.9874 - val_binary_accuracy: 0.9874
